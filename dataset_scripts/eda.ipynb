# %%
from datasets import load_dataset
from transformers import AutoTokenizer
import re
from collections import defaultdict
import pandas as pd
import matplotlib.pyplot as plt

repo_id='lmqg/qg_koquad'
dataset = load_dataset(repo_id)

# %%
print('train에 들어있는 데이터의 갯수는', len(dataset['train']))
print('validation에 들어있는 데이터의 갯수는', len(dataset['validation']))
print('test에 들어있는 데이터의 갯수는', len(dataset['test']))
# Out:
# train에 들어있는 데이터의 갯수는 54556
# validation에 들어있는 데이터의 갯수는 5766
# test에 들어있는 데이터의 갯수는 5766

# %%
# all_data = dataset.to_pandas() 이건 안되네.
train_data = dataset['train'].to_pandas()

# %%
train_data.to_csv('./qg_koquad_train.csv')
train_data_essential = train_data[['answer','question','paragraph']]
train_data_essential.to_csv('./qg_koquad_train_essential.csv')

# %%
def percentile(n):
    def percentile_(x):
        return x.quantile(n)
    percentile_.__name__ = 'percentile_{:02.0f}'.format(n*100)
    
    return percentile_

print("단어 단위 지문 길이(95 percentile) =",\
      train_data['paragraph'].apply(lambda x: len(x.split(' '))).agg([percentile(0.95)]).values[0])

train_data['len'] = train_data['paragraph'].apply(lambda x: len(x.split(' ')))
print(train_data.agg({'len':['min', 'max', 'mean']}))
# Out:
# 단어 단위 지문 길이(95 percentile) = 193.0
#               len
# min     47.000000
# max   2244.000000
# mean   115.320001

# %%
# bins = list(range(0, train_data['len'].max(), train_data['len'].max()/10))
import numpy as np
bins = list(np.arange(0, train_data['len'].max(), train_data['len'].max()/10).astype(int))
sentence_len_categories = pd.cut(train_data["len"], bins)
print(sentence_len_categories.value_counts(normalize=True))
sentence_len_categories.value_counts(normalize=True).sort_index().plot(kind="bar")
# Out:
# len
# (0, 224]        0.973161
# (224, 448]      0.026032
# (448, 673]      0.000807
# (673, 897]      0.000000
# (897, 1122]     0.000000
# (1122, 1346]    0.000000
# (1346, 1570]    0.000000
# (1570, 1795]    0.000000
# (1795, 2019]    0.000000
# Name: proportion, dtype: float64
# <Axes: xlabel='len'>

# %%
tokenizer = AutoTokenizer.from_pretrained('klue/bert-base')

print("토큰 단위 문장 길이(95 percentile) =",\
      train_data['paragraph'].apply(lambda x: len(tokenizer(x)['input_ids'])).agg([percentile(0.95)]).values[0])

train_data['token_len'] = train_data['paragraph'].apply(lambda x: len(tokenizer(x)['input_ids']))
print(train_data.agg({'token_len':['min', 'max', 'mean']}))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (557 > 512). Running this sequence through the model will result in indexing errors
# 토큰 단위 문장 길이(95 percentile) = 459.0
#         token_len
# min    149.000000
# max   5874.000000
# mean   275.216035

# %%
not_en_ko_num_pattern = re.compile('[^ㄱ-ㅎ가-힣a-zA-Z0-9\s]')
known_special_chars_dict = defaultdict(int)

for sentence in train_data['paragraph']:
    special_chars = not_en_ko_num_pattern.findall(sentence)
    if len(special_chars) != 0 :
        for char in special_chars:
            if tokenizer.tokenize(char) != ['[UNK]']:
                known_special_chars_dict[char] += 1

print("klue/bert-base가 알고 있는 특수문자 개수 =", len(known_special_chars_dict))
print(known_special_chars_dict)
# Out:
# klue/bert-base가 알고 있는 특수문자 개수 = 440
# defaultdict(<class 'int'>, {'.': 406494, '“': 8496, ',': 294334, '”': 8421, '(': 96785, ')': 96716, '《': 25442, '》': 25434, '&': 1079, '~': 5897, '‘': 8907, '’': 8908, '〈': 8794, '〉': 8800, 'の': 298, '・': 338, '/': 3338, '…': 645, '-': 14746, '情': 46, '歌': 181, ':': 7322, '州': 434, '大': 1058, '國': 716, '·': 16211, '內': 132, '山': 511, '道': 452, '海': 231, '本': 248, '福': 94, '島': 261, '宮': 206, '城': 362, '手': 75, '靑': 42, '田': 272, "'": 40108, '"': 65453, '=': 260, '[': 1120, ']': 1056, '²': 115, '生': 199, '社': 130, '<': 2749, '>': 2759, '光': 265, '金': 804, '宗': 564, '武': 365, '然': 18, '八': 86, '通': 197, '%': 6274, '水': 207, ';': 776, '?': 1275, '法': 365, '祖': 225, '別': 80, '子': 474, '小': 286, '不': 126, '野': 128, 'é': 570, '長': 282, '基': 166, '敎': 378, '!': 1518, 'ℓ': 391, '→': 374, '+': 860, '記': 140, '∼': 356, '地': 258, '方': 262, '時': 182, '#': 96, '_': 57, '商': 99, '務': 80, '合': 199, '陽': 158, '德': 268, '司': 240, '憲': 135, '府': 278, '平': 319, '文': 548, 'Ⅱ': 240, '鄭': 185, '元': 328, '○': 182, '非': 93, '理': 152, '政': 332, '經': 170, '禮': 157, '論': 86, '體': 166, '制': 180, '王': 773, '公': 212, '人': 428, '間': 74, '的': 134, '任': 59, '期': 115, '重': 99, '正': 425, '限': 31, '界': 65, '條': 103, '木': 125, '成': 377, '『': 261, '』': 255, '≪': 236, '≫': 236, '開': 109, '花': 125, '天': 416, '古': 192, '韓': 276, '民': 262, '保': 166, '黨': 95, '三': 393, '史': 200, '前': 227, '戰': 176, '世': 302, 'ㆍ': 312, '百': 91, '家': 253, '℃': 111, '心': 156, '之': 109, '有': 77, '無': 140, '我': 31, '空': 105, '眞': 64, '至': 48, '軍': 562, '都': 192, '中': 529, '外': 91, '事': 250, '義': 478, '親': 253, '五': 109, '使': 201, '上': 244, '將': 134, '會': 267, '議': 76, '所': 93, '判': 63, '傳': 125, '安': 312, '南': 222, '對': 74, '*': 188, '川': 216, '與': 31, '信': 107, '來': 11, '先': 81, '反': 155, '官': 241, '士': 173, '用': 46, '濟': 173, '雲': 25, '龍': 178, '立': 177, '說': 94, '「': 944, '」': 944, '神': 282, '明': 368, '女': 218, '報': 57, '－': 66, '新': 364, '者': 100, '林': 152, '實': 103, '錄': 61, '仁': 354, '西': 162, '原': 211, '院': 206, '君': 182, '白': 185, '江': 152, '村': 56, '，': 62, '東': 370, '十': 119, '門': 156, '二': 104, '名': 120, '權': 255, '告': 47, '故': 109, '出': 49, '學': 627, '母': 62, 'Ⅰ': 48, '帝': 285, '愛': 87, '受': 32, '運': 133, '化': 179, '英': 228, '氏': 226, '高': 220, '族': 19, '口': 69, '淸': 337, '京': 121, '北': 172, '華': 98, '和': 291, '日': 287, '數': 78, '年': 128, '朝': 278, '鮮': 82, '`': 390, '書': 314, '|': 16, '美': 206, '形': 79, '定': 154, '字': 97, '師': 104, '代': 111, '式': 75, '知': 181, '$': 155, '男': 61, '色': 21, '：': 121, '郞': 43, '月': 63, 'е': 219, 'о': 307, '行': 303, '×': 256, 'и': 235, 'т': 139, 'а': 235, 'р': 159, '風': 87, '作': 49, '集': 114, '節': 90, '朴': 170, '意': 80, '吉': 178, '＜': 94, '＞': 94, '聖': 204, '寺': 124, '漢': 100, '修': 92, '堂': 133, '全': 154, '食': 12, '物': 104, '典': 107, '}': 92, '\u200b': 43, '㈜': 8, '甲': 100, '如': 26, '佛': 47, '治': 156, '章': 116, '決': 12, '共': 48, '主': 272, '後': 116, '利': 131, '觀': 21, '業': 94, '發': 85, '動': 165, '資': 37, '自': 105, '善': 105, '周': 92, '當': 14, '—': 74, 'ｍ': 41, '河': 105, '下': 146, '志': 82, '四': 184, '統': 104, '由': 41, '父': 54, '多': 70, '約': 127, '表': 49, '面': 74, 'с': 136, '關': 80, '馬': 186, '；': 32, '現': 89, '擧': 59, '員': 35, '例': 23, '第': 49, '市': 42, '言': 88, '張': 118, '太': 261, 'Ⅲ': 48, 'н': 163, '圖': 148, '契': 22, '規': 35, '一': 342, '銀': 29, '場': 17, '孫': 75, '獨': 60, '＝': 59, '要': 57, '兵': 119, '臣': 221, '求': 24, '近': 45, '相': 147, '己': 44, '土': 110, '惡': 33, '萬': 93, '選': 49, '機': 56, '石': 141, '度': 85, '産': 30, '㏊': 24, '力': 85, '車': 59, '廣': 90, '^': 82, '支': 16, '富': 19, '•': 115, '害': 8, '異': 40, '夫': 84, '春': 86, 'ㅡ': 13, '①': 41, '②': 41, '③': 37, '④': 27, '⑤': 21, '⑥': 11, '⑦': 11, '命': 83, '部': 116, '常': 33, '可': 36, '能': 32, '分': 91, '私': 61, '―': 75, '黃': 101, '氣': 42, '性': 119, '‧': 40, '株': 15, '見': 34, '語': 111, '【': 66, '】': 66, '∙': 116, '想': 32, '@': 34, '以': 34, '火': 54, '則': 26, '詩': 66, '․': 16, '在': 55, '{': 49, '入': 52, '％': 17, '處': 29, '同': 146, '得': 33, 'ㅣ': 8, '思': 37, '是': 75, '證': 6, '九': 71, '七': 61, '\u200e': 8, '爲': ...

# %%
not_en_ko_num_pattern = re.compile('[^ㄱ-ㅎ가-힣a-zA-Z0-9\s]')
unk_special_chars_dict = defaultdict(int)

for sentence in train_data['paragraph']:
    special_chars = not_en_ko_num_pattern.findall(sentence)
    if len(special_chars) != 0 :
        for char in special_chars:
            tokenizer.tokenize(char)
            if tokenizer.tokenize(char) == ['[UNK]']:
                unk_special_chars_dict[char] += 1

print("klue/bert-base가 모르는 특수문자 개수 =", len(unk_special_chars_dict))
print(unk_special_chars_dict)
# Out:
# klue/bert-base가 모르는 특수문자 개수 = 2498
# defaultdict(<class 'int'>, {'ß': 38, 'Ö': 10, '飾': 26, 'り': 116, 'じ': 30, 'ゃ': 21, 'な': 73, 'い': 203, 'よ': 56, '涙': 17, 'は': 44, 'ミ': 21, 'ア': 70, 'モ': 43, 'ー': 279, 'レ': 78, '熱': 20, '姬': 32, '素': 32, '顔': 25, 'ま': 84, 'で': 56, '⁄': 62, '陸': 74, '奥': 21, '国': 152, '遠': 65, '畿': 16, '岩': 26, '森': 79, '秋': 63, '電': 88, '李': 518, '魯': 23, '鎬': 6, '達': 78, '篤': 15, '恭': 79, '殿': 145, '洪': 131, 'Š': 6, 'ų': 6, '⅓': 16, '諡': 61, '衆': 71, '遷': 7, '位': 116, '帳': 11, 'ε': 34, 'ν': 78, 'ύ': 11, 'δ': 49, 'ρ': 81, 'α': 190, '交': 53, '泰': 70, '弘': 117, 'è': 106, '永': 154, '失': 31, '楽': 44, '園': 103, '系': 51, '沙': 40, '督': 27, 'ə': 94, 'ˈ': 92, 'ɪ': 38, 'ʊ': 34, 'Κ': 24, 'λ': 88, 'ι': 100, 'σ': 72, 'τ': 93, 'ώ': 14, '–': 861, '密': 48, '旨': 39, '備': 48, '忘': 15, '半': 47, '÷': 15, 'χ': 21, '組': 63, '坊': 36, '持': 44, '尹': 127, '沔': 15, '汝': 22, '良': 129, '津': 77, '淳': 26, '千': 76, '訟': 25, '爭': 38, '喪': 11, '服': 21, '凡': 11, '⅔': 15, '改': 48, '項': 28, '拜': 13, '楠': 20, '黑': 48, '屠': 14, '殺': 50, '守': 138, '納': 51, '采': 14, '品': 65, '醬': 8, '豉': 8, '工': 83, 'ヨ': 5, 'ン': 162, '様': 5, 'ノ': 7, 'ム': 41, 'た': 80, 'ん': 81, '盛': 61, '滋': 5, '丁': 72, 'μ': 51, '⁴': 4, 'η': 53, 'κ': 86, 'ό': 29, 'Π': 24, 'έ': 30, 'γ': 60, 'ο': 123, 'ς': 160, 'Λ': 9, 'β': 68, 'υ': 47, '齊': 41, '放': 28, '鳴': 15, '剛': 31, '昧': 4, '源': 114, '淨': 8, '俱': 9, '諦': 10, '俗': 13, '湛': 2, '寂': 2, '照': 6, '渦': 7, '流': 93, '導': 39, '壁': 34, '營': 74, '摠': 21, '諸': 51, '興': 170, '衛': 302, '房': 83, '附': 17, '評': 19, '趾': 7, '郡': 132, 'そ': 27, 'れ': 45, 'ぬ': 49, '綿': 10, '星': 133, 'ł': 113, '梁': 46, '封': 26, '號': 101, '惠': 113, '徳': 33, '列': 35, '去': 3, '°': 391, '鉛': 7, '直': 67, '緣': 31, '瓣': 7, '量': 20, '轉': 16, 'á': 122, 'ê': 12, 'ậ': 7, 'ệ': 7, 'ñ': 9, '嘉': 89, '驛': 23, '屬': 37, '禧': 57, '著': 13, '才': 15, '昌': 70, '始': 63, '初': 51, '楊': 69, '緯': 7, '香': 57, '港': 66, 'ç': 54, '奇': 25, '今': 57, '、': 61, '贈': 7, 'あ': 26, 'が': 33, 'と': 93, 'う': 106, '超': 39, '抗': 74, '訴': 41, '末': 39, '顚': 8, '倒': 12, '菜': 44, '姫': 33, 'コ': 42, 'ズ': 24, 'ス': 133, 'ロ': 91, 'シ': 24, 'ョ': 27, '少': 63, '珖': 6, '助': 19, '防': 31, '宣': 72, '邊': 36, '柳': 135, 'ü': 184, '㎚': 24, '輝': 52, '線': 102, '蘇': 70, '參': 59, '舊': 79, '承': 118, '疇': 8, '壽': 74, '芑': 5, '順': 107, '朋': 5, '齡': 13, '廠': 16, '衙': 25, '進': 58, '試': 90, '−': 43, '怨': 7, '旱': 7, '災': 31, '体': 19, '護': 103, '諭': 51, '匪': 33, '徒': 53, '創': 25, '唱': 33, '劇': 97, '剿': 5, '撫': 28, '鄕': 53, '團': 114, '訓': 82, 'θ': 14, '±': 59, '料': 3, '鉄': 23, '塔': 26, '刺': 25, '赤': 46, '坪': 12, '阿': 86, '幕': 39, '牧': 46, '胡': 23, '科': 79, 'ó': 141, '慶': 212, '乾': 106, '隆': 101, '覺': 42, '羅': 94, '顒': 11, '琰': 29, 'ᡝ': 56, 'ᠠ': 134, 'ᡳ': 100, 'ᠰ': 36, 'ᠨ': 140, 'ᡤ': 26, 'ᠣ': 50, 'ᡵ': 16, 'ᠶ': 22, 'ᠩ': 20, '敷': 12, '綏': 16, '猷': 4, '崇': 55, '裕': 33, '孝': 162, '勤': 27, '儉': 22, '端': 58, '敏': 6, '哲': 34, '睿': 81, '皇': 386, 'š': 4, '儀': 84, '純': 62, '后': 97, '魏': 15, '佳': 10, '砂': 18, '琴': 18, '鼻': 17, '笛': 5, '弓': 31, '御': 84, '曲': 99, '管': 90, '樂': 128, '雜': 3, '念': 11, '否': 28, '震': 34, 'ひ': 16, 'し': 99, 'に': 43, 'ほ': 19, 'だ': 10, 'さ': 52, 'ú': 29, '級': 31, '∑': 7, 'Σ': 19, '夜': 40, '卿': 36, '羲': 13, '圭': 14, '角': 21, '翰': 36, '板': 11, '寫': 29, '趙': 78, '軟': 11, '範': 35, '型': 43, '絿': 5, '鍾': 26, '彦': 23, '草': 53, '濩': 5, '晉': 36, '匡': 13, '喜': 40, '謄': 5, '骨': 29, '音': 47, '猿': 13, '若': 23, '遊': 28, '派': 93, '舞': 70, '伎': 25, '冷': 12, 'ש': 14, 'ר': 50, 'ך': 6, 'א': 24, 'ג': 32, 'ן': 19, 'ה': 132, 'ס': 18, 'ל': 6, 'י': 66, 'ח': 14, 'מ': 12, 'ז': 10, 'Б': 20, 'л': 87, 'ы': 33, 'й': 71, 'д': 69, 'м': 67, '嗣': 22, '幸': 19, 'к': 134, 'п': 64, 'Н': 6, 'ğ': 23, 'ş': 15, 'ı': 11, 'ă': 14, '題': 20, '詠': 13, '類': 45, '敍': 21, '藤': 118, '顯': 69, '輔': 35, '幽': 8, '玄': 66, '左': 52, '俊': 62, '境': 13, '收': 35, '感': 33, '謝': 27, '菊': 10, '崎': 45, '雄': 57, '丸': 21, '鶴': 66, '洞': 98, '琿': 8, '埈': 5, '鎔': 5, '製': 7, '老': 64, '縣': 195, '令': 73, '豊': 95, '儲': 23, '倉': 41, '龔': 3, '吳': 84, '希': 23, '孟': 3, '詔': 8, '接': 3, '從': 13, '簿': 36, '僉': 16, '均': 35, '館': 77, '⋅': 7, '敗': 11, '爀': 15, ...
